# %% [markdown]
# # Sales vs Advertising Analysis**Objective:** Build a linear regression model to understand the relationship between advertising expenditure and sales, enabling data-driven marketing budget optimization.**Approach Overview:**1. Data Exploration â€” Visualize sales and advertising relationships2. Correlation Analysis â€” Identify key drivers of sales performance3. Linear Regression Modeling â€” Quantify advertising-to-sales impact4. Model Interpretation â€” Extract actionable marketing insights5. Business Application â€” Enable ROI-driven budget allocation

# %% [markdown]
# # Executive Summary## Linear Regression: Sales vs Advertising AnalysisThis project applies linear regression to quantify the impact of advertising on sales, enabling:- **ROI Measurement:** Calculate revenue generated per dollar of advertising spend- **Budget Optimization:** Allocate marketing resources to maximize sales impact- **Forecasting:** Predict sales under different advertising scenarios- **Performance Tracking:** Monitor advertising effectiveness over time**Dataset Overview:**- Mobile and tablet retailer sales and advertising spend data- Regional and temporal sales patterns- Historical advertising investment and corresponding sales outcomes**Regression Analysis:**- Exploratory data visualization of sales-advertising relationships- Linear regression model for direct sales prediction- Model diagnostics and validation (RÂ², RMSE, residuals)- Interpretation of regression coefficients as marketing multipliers**Expected Insights:**- Clear monetization metrics for advertising investments- Optimal budget allocation recommendations- Forecasting capability for sales planning---

# %% [markdown]
# # Sales vs Advertising Analysis
#
# **Objective:** Build a linear regression model to understand the relationship between advertising expenditure and sales, enabling data-driven marketing budget optimization.
#
# **Approach Overview:**
# 1. Data Exploration — Visualize sales and advertising relationships
# 2. Correlation Analysis — Identify key drivers of sales performance
# 3. Linear Regression Modeling — Quantify advertising-to-sales impact
# 4. Model Interpretation — Extract actionable marketing insights
# 5. Business Application — Enable ROI-driven budget allocation

# %% [markdown]
# # Executive Summary
#
# ## Linear Regression: Sales vs Advertising Analysis
#
# This project applies linear regression to quantify the impact of advertising on sales, enabling:
#
# - **ROI Measurement:** Calculate revenue generated per dollar of advertising spend
# - **Budget Optimization:** Allocate marketing resources to maximize sales impact
# - **Forecasting:** Predict sales under different advertising scenarios
# - **Performance Tracking:** Monitor advertising effectiveness over time
#
# **Dataset Overview:**
# - Mobile and tablet retailer sales and advertising spend data
# - Regional and temporal sales patterns
# - Historical advertising investment and corresponding sales outcomes
#
# **Regression Analysis:**
# - Exploratory data visualization of sales-advertising relationships
# - Linear regression model for direct sales prediction
# - Model diagnostics and validation (R², RMSE, residuals)
# - Interpretation of regression coefficients as marketing multipliers
#
# **Expected Insights:**
# - Clear monetization metrics for advertising investments
# - Optimal budget allocation recommendations
# - Forecasting capability for sales planning
#
# ---

# %% [markdown]
# <center><font size=8>Hands-on - Linear Regression</font></center>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## **Business Context**

# %% [markdown]
# In the dynamic and competitive market of mobiles and tablets, retailers need to be aware of market trends and adapt to changing consumer preferences and technological advancements. They also need to efficiently manage inventory and marketing strategies to attract new customers and retain existing ones, ensuring sustained growth and profitability.
#
# A renowned online retailer faces the challenge of managing inventory and managing marketing expenditures. To address these challenges, the retailer aims to accurately forecast sales to make informed decisions regarding inventory management and resource allocation. The end goal is to minimize stockouts and overstock situations and enhance sales performance to gain a competitive advantage.

# %% [markdown]
# ## **Objective**

# %% [markdown]
# As a data scientist, you are provided with sales data from the recent past along with other attributes like pricing strategies, promotional activities, and customer engagement. You are required to analyze the data, identify patterns, and build a linear regression model to forecast sales.

# %% [markdown]
# ## **Data Dictionary**

# %% [markdown]
# 1. **`Advertising Expenditure`**: Amount spent on advertisements (in dollars) across different marketing channels
# 2. **`Campaign Engagement Score`**: A score computed by the marketing team based on the engagement (likes, comments, shares) on social media campaigns
# 3. **`Discount Percentage`**: Average discount offered for a given product
# 4. **`Average Customer Rating`**: Average rating provided by customers for the product
# 5. **`Product Price`**: The price of the product (in dollars)
# 6. **`Return Rate`**: The average rate of return once the product has been delivered
# 7. **`Length of Product Description`**: Number of words in the description of the product
# 8. **`Region`**: Region where the product is sold (North, South, East, or West)
# 9. **`Popularity`**: The level of popularity of the product (ranges from very low to very high)
# 10. **`Sales`**: Amount of sales (in dollars)

# %% [markdown]
# **Note**: Product here refers to a mobile or a tablet.

# %% [markdown]
# # **Importing the necessary libraries**

# %% [markdown]
# # **Loading the data**

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# ## **Checking the first 5 rows**

# %% [markdown]
# ## **Checking the shape of the data**

# %% [markdown]
# * The dataset has 3000 rows and 10 columns.

# %% [markdown]
# ## **Checking the attribute types**

# %% [markdown]
# * There are 8 numerical and 2 categorical variables in the data.

# %% [markdown]
# ## **Checking the statistical summary**

# %% [markdown]
# * On an average, the retailer has sold mobiles and tablets worth ~$24k.
# * On an average, ~600 dollars have been spent on adversiting.
# * The mobiles and tablets sold by the retailer are priced between 10 to 2000 dollars approx.

# %% [markdown]
# ## **Checking for missing values**

# %% [markdown]
# * There are no missing values in the data

# %% [markdown]
# ## **Checking for duplicate values**

# %% [markdown]
# * There are no duplicate values in the data

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# * Sales, Advertising Expenditure, Discount Percentage, and Product Price exhibit left-skewed distributions.
# * Return Rate exhibits a right-skewed distribution.
# * Campaign Engagement Score and Length of Product Description are approx. normally distributed.

# %% [markdown]
# * There are outliers in all the attributes in the data.

# %% [markdown]
# * The North region has slightly fewer data points than the others.
# * Most of the mobiles and tablets sold are very popular, and only a negligible amount of them are very unpopular.

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# - Sales seem to be positively correlated with Advertising Expenditure, Campaign Engagement Score, and Average Customer Rating.
# - Sales seem to be negatively correlated with Product Price and Return Rate.

# %% [markdown]
# - Sales is indeed highly positively correlated with Advertising Expenditure.
# - Sales are indeed negatively correlated with Product Price and Return Rate, but the strength of the correlation is low.
# - Advertising Expenditure and Campaign Engagement Score are positively correlated.
# - Return Rate and Average Customer Rating are negatively correlated.

# %% [markdown]
# * We observe lower sales for unpopular products.

# %% [markdown]
# * Sales seem to be uniform across different regions.

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Simple Linear Regression - `Sales` vs `Advertising Expenditure`**

# %% [markdown]
# We first separate the data into training and test sets.

# %% [markdown]
# Now, we build the linear regression model.

# %% [markdown]
# ## **Multiple Linear Regression - `Sales` vs `Advertising Expenditure`, `Discount Percentage`, `Product Price`**

# %% [markdown]
# ## **Multiple Linear Regression - `Sales` vs All independent variables**

# %% [markdown]
# We first need to label encode the `Popularity` column.

# %% [markdown]
# Next, we need to one-hot encode the `Region` column.

# %% [markdown]
# * Note that the dummy variable corresponding to the '*East*' category has been dropped.

# %% [markdown]
# Now, we build the linear regression model.

# %% [markdown]
# # **Model Performance Evaluation**

# %% [markdown]
# We first define a function to collate all the evaluation metrics into a single dataframe.

# %% [markdown]
# We'll now check the performance of all the models we've built so far.

# %% [markdown]
# ## **Simple Linear Regression - `Sales` vs `Advertising Expenditure`**

# %% [markdown]
# ## **Multiple Linear Regression - `Sales` vs `Advertising Expenditure`, `Discount Percentage`, `Product Price`**

# %% [markdown]
# ## **Multiple Linear Regression - `Sales` vs All independent variables**

# %% [markdown]
# # **Model Performance Comparison**

# %% [markdown]
# We'll now compare the performances of all the models we built.

# %% [markdown]
# * Advertising Expenditure seems to be a good predictor of Sales.
# * Discount Percentage and Product Price, when combined with Advertising Expenditure, they together provide good predictive power.
# * The final model with all independent variables exhibits the best performance.

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)
# Out:
# ============================================================
# BOOTSTRAP
# ============================================================
# Project root: C:\Projects\GenerativeAI
# ============================================================

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)
# Out:
# ============================================================
# LOAD CONFIG
# ============================================================
# Project name: GenerativeAI
# ✓ Config loaded
# ============================================================

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)
# Out:
# ============================================================
# IMPORTS & SETUP
# ============================================================
# ✓ Utils imported
# ✓ Libraries imported
# ✓ Seed set to 42
# ============================================================

# %%
# Load the sales dataset
sales = load_csv('sales/Sales.csv')

# %%
# creating a copy of the data
data = sales.copy()

# %%
data.head(5)
# Out:
#    Advertising Expenditure  Campaign Engagement Score  Discount Percentage  \
# 0               644.049317                  54.565531            25.267151
# 1               521.483294                  46.875226            35.075859
# 2               540.079510                  42.287145            12.618381
# 3               627.938419                  61.825441            31.588445
# 4               471.149948                  31.061512             9.198991
#
#    Average Customer Rating  Product Price  Return Rate  \
# 0                 4.604634    1599.575723     2.133580
# 1                 4.358693    1586.464404     1.553437
# 2                 4.571018    1301.644856     2.274891
# 3                 4.234209    1601.041884     1.035971
# 4                 4.816215    1496.734345     3.276840
#
#    Length of Product Description Region Popularity        Sales
# 0                     231.185389   East       High  26246.91291
# 1                     262.686931   West  Very High  21432.16935
# 2                     324.347319  South  Very High  22551.92436
# 3                     447.710984  South  Very High  27792.29446
# 4                     310.055333   East   Moderate  17354.77148

# %%
data.shape
# Out:
# (3000, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Advertising Expenditure        3000 non-null   float64
#  1   Campaign Engagement Score      3000 non-null   float64
#  2   Discount Percentage            3000 non-null   float64
#  3   Average Customer Rating        3000 non-null   float64
#  4   Product Price                  3000 non-null   float64
#  5   Return Rate                    3000 non-null   float64
#  6   Length of Product Description  3000 non-null   float64
#  7   Region                         3000 non-null   object
#  8   Popularity                     3000 non-null   object
#  9   Sales                          3000 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 234.5+ KB

# %%
data.describe()
# Out:
#        Advertising Expenditure  Campaign Engagement Score  \
# count              3000.000000                3000.000000
# mean                607.727150                  49.456305
# std                  82.025112                  13.171290
# min                  97.250000                   0.000000
# 25%                 561.984787                  40.697530
# 50%                 616.116596                  49.478699
# 75%                 666.331853                  58.150891
# max                 801.500000                  98.750000
#
#        Discount Percentage  Average Customer Rating  Product Price  \
# count          3000.000000              3000.000000    3000.000000
# mean             28.997927                 4.408783    1434.718134
# std               4.700923                 0.227823     222.832467
# min               0.000000                 3.649450       9.780000
# 25%              26.222998                 4.251118    1306.155958
# 50%              29.552853                 4.432254    1461.301831
# 75%              32.259294                 4.583205    1587.671790
# max              40.540000                 4.874450    2000.560000
#
#        Return Rate  Length of Product Description         Sales
# count  3000.000000                    3000.000000   3000.000000
# mean      1.666106                     248.696636  23858.638609
# std       0.900435                      60.800024   3611.748810
# min       0.033720                      42.000000   3257.595426
# 25%       0.954551                     207.076217  21632.968838
# 50%       1.537856                     249.348398  24087.129995
# 75%       2.285394                     288.875650  26421.772433
# max       4.534866                     496.000000  34421.427430

# %%
data.isnull().sum()
# Out:
# Advertising Expenditure          0
# Campaign Engagement Score        0
# Discount Percentage              0
# Average Customer Rating          0
# Product Price                    0
# Return Rate                      0
# Length of Product Description    0
# Region                           0
# Popularity                       0
# Sales                            0
# dtype: int64

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# defining the figure size
plt.figure(figsize=(15, 10))

# defining the list of numerical features to plot
features = data.select_dtypes(include=['number']).columns.tolist()

# creating the histograms
for i, feature in enumerate(features):
    plt.subplot(3, 3, i+1)    # assign a subplot in the main plot
    sns.histplot(data=data, x=feature)    # plot the histogram

plt.tight_layout()    # to add spacing between plots
plt.show()

# %%
# defining the figure size
plt.figure(figsize=(15, 10))

# defining the list of numerical features to plot
features = data.select_dtypes(include=['number']).columns.tolist()

# creating the histograms
for i, feature in enumerate(features):
    plt.subplot(3, 3, i+1)    # assign a subplot in the main plot
    sns.boxplot(data=data, x=feature)    # plot the histogram

plt.tight_layout()    # to add spacing between plots
plt.show()

# %%
# defining the figure size
plt.figure(figsize=(10, 5))

# defining the list of categorical features to plot
features = data.select_dtypes(exclude=['number']).columns.tolist()

# creating the histograms
for i, feature in enumerate(features):
    plt.subplot(1, 2, i+1)    # assign a subplot in the main plot
    sns.countplot(data=data, x=feature)    # plot the histogram

plt.tight_layout()    # to add spacing between plots
plt.show()

# %%
sns.pairplot(data);

# %%
# defining the figure size
plt.figure(figsize=(10, 7))

# plotting the correlation heatmap
sns.heatmap(data.corr(numeric_only = True), annot=True, fmt='0.2f', cmap='coolwarm');

# %%
sns.boxplot(data=data, y='Sales', x='Popularity');

# %%
sns.boxplot(data=data, y='Sales', x='Region');

# %%
# defining the explanatory (independent) and response (dependent) variables
X = data.drop('Sales', axis=1)
y = data['Sales']

# %%
# splitting the data in 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X,    # specifying the independent variables
    y,    # specifying the dependent variable
    test_size=0.20,    # specifying the size of the test set as a fraction of the whole data
    random_state=42    # specifying a seed value to enable reproducible results
)

# %%
# defining the independent variable
ind_vars1 = ['Advertising Expenditure']

# %%
# creating an instance of the linear regression model
lin_reg1 = LinearRegression()

# fitting the model to the training data
lin_reg1.fit(X_train[ind_vars1], y_train)
# Out:
# LinearRegression()

# %%
# printing the linear regression coefficients
print(
    "Slope:", lin_reg1.coef_,
    "Intercept:", lin_reg1.intercept_,
)
# Out:
# Slope: [28.66748755] Intercept: 6435.891302271026

# %%
# printing the linear regression equation
print(
    "Sales =",
     "(", lin_reg1.coef_[0], ")", "*", ind_vars1[0],
    "+", lin_reg1.intercept_,
)
# Out:
# Sales = ( 28.667487552010247 ) * Advertising Expenditure + 6435.891302271026

# %%
# plotting the best-fit line
fitted_values1 = lin_reg1.predict(X_train[ind_vars1])

# Plot the scatterplot and regression line
plt.scatter(X_train[ind_vars1], y_train)
plt.plot(X_train[ind_vars1], fitted_values1, color='blue')
plt.xlabel(ind_vars1[0])
plt.ylabel('Sales')
plt.show()

# %%
# defining the independent variables
ind_vars2 = ['Advertising Expenditure', 'Discount Percentage', 'Product Price']

# %%
# creating an instance of the linear regression model
lin_reg2 = LinearRegression()

# fitting the model to the training data
lin_reg2.fit(X_train[ind_vars2], y_train)
# Out:
# LinearRegression()

# %%
# printing the linear regression coefficients
print(
    "Coefficients:", lin_reg2.coef_, lin_reg2.intercept_
)
# Out:
# Coefficients: [38.43656519 -3.57483935 -8.4559953 ] 12731.131575406751

# %%
# printing the linear regression equation
print(
    "Sales =",
    "(", lin_reg2.coef_[0], ")", "*", ind_vars2[0],
    "+ (", lin_reg2.coef_[1], ")", "*", ind_vars2[1],
    "+ (", lin_reg2.coef_[2], ")", "*", ind_vars2[2],
    "+", lin_reg2.intercept_,
)
# Out:
# Sales = ( 38.43656519116551 ) * Advertising Expenditure + ( -3.574839346817983 ) * Discount Percentage + ( -8.455995295705073 ) * Product Price + 12731.131575406751

# %%
# defining the label encoding
lab_enc = {
    'Very Low': 1,
    'Low': 2,
    'Moderate': 3,
    'High': 4,
    'Very High': 5,
}

# %%
# encoding the Popularity column
X['Popularity'] = X['Popularity'].map(
    lambda x: lab_enc[x]
)

X.head()
# Out:
#    Advertising Expenditure  Campaign Engagement Score  Discount Percentage  \
# 0               644.049317                  54.565531            25.267151
# 1               521.483294                  46.875226            35.075859
# 2               540.079510                  42.287145            12.618381
# 3               627.938419                  61.825441            31.588445
# 4               471.149948                  31.061512             9.198991
#
#    Average Customer Rating  Product Price  Return Rate  \
# 0                 4.604634    1599.575723     2.133580
# 1                 4.358693    1586.464404     1.553437
# 2                 4.571018    1301.644856     2.274891
# 3                 4.234209    1601.041884     1.035971
# 4                 4.816215    1496.734345     3.276840
#
#    Length of Product Description Region  Popularity
# 0                     231.185389   East           4
# 1                     262.686931   West           5
# 2                     324.347319  South           5
# 3                     447.710984  South           5
# 4                     310.055333   East           3

# %%
# creating one-hot encoded (also called dummy) variables
X = pd.get_dummies(
    X,    # defining the dataframe from where to fetch the data
    columns=X.select_dtypes(include=["object", "category"]).columns.tolist(),    # defining the type of columns for which dummies will be made
    drop_first=True,    # dropping the first dummy column
)

# specifying the datatype of the independent variables dataframe
X = X.astype(float)

X.head()
# Out:
#    Advertising Expenditure  Campaign Engagement Score  Discount Percentage  \
# 0               644.049317                  54.565531            25.267151
# 1               521.483294                  46.875226            35.075859
# 2               540.079510                  42.287145            12.618381
# 3               627.938419                  61.825441            31.588445
# 4               471.149948                  31.061512             9.198991
#
#    Average Customer Rating  Product Price  Return Rate  \
# 0                 4.604634    1599.575723     2.133580
# 1                 4.358693    1586.464404     1.553437
# 2                 4.571018    1301.644856     2.274891
# 3                 4.234209    1601.041884     1.035971
# 4                 4.816215    1496.734345     3.276840
#
#    Length of Product Description  Popularity  Region_North  Region_South  \
# 0                     231.185389         4.0           0.0           0.0
# 1                     262.686931         5.0           0.0           0.0
# 2                     324.347319         5.0           0.0           1.0
# 3                     447.710984         5.0           0.0           1.0
# 4                     310.055333         3.0           0.0           0.0
#
#    Region_West
# 0          0.0
# 1          1.0
# 2          0.0
# 3          0.0
# 4          0.0

# %%
# splitting the data in 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X,    # specifying the independent variables
    y,    # specifying the dependent variable
    test_size=0.20,    # specifying the size of the test set as a fraction of the whole data
    random_state=42    # specifying a seed value to enable reproducible results
)

# %%
# creating an instance of the linear regression model
lin_reg3 = LinearRegression()

# fitting the model to the training data
lin_reg3.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# printing the linear regression coefficients
print(
    "Coefficients:", lin_reg3.coef_, lin_reg3.intercept_
)
# Out:
# Coefficients: [ 3.68003768e+01  2.07776337e+01 -6.91846629e+00  2.89027810e+03
#  -8.67003378e+00 -4.44787734e+02 -5.08833857e-02  1.46842283e+02
#  -6.98114448e+00  5.28817618e+01  1.89167361e+02] 469.5990299010082

# %%
# printing the linear regression equation
equation = "Sales = ( " + str(lin_reg3.coef_[0]) + " ) * " + X_train.columns.tolist()[0]

for i in range(1, lin_reg3.coef_.shape[0]):
    equation += " + ( " + str(lin_reg3.coef_[i]) + " ) * " + X_train.columns.tolist()[i]

equation +=  " + " + str(lin_reg3.intercept_)

print(equation)
# Out:
# Sales = ( 36.800376844421834 ) * Advertising Expenditure + ( 20.77763369824629 ) * Campaign Engagement Score + ( -6.9184662912999535 ) * Discount Percentage + ( 2890.278101515822 ) * Average Customer Rating + ( -8.670033784471643 ) * Product Price + ( -444.7877341802194 ) * Return Rate + ( -0.05088338568133863 ) * Length of Product Description + ( 146.84228310853334 ) * Popularity + ( -6.981144476912625 ) * Region_North + ( 52.88176184795639 ) * Region_South + ( 189.16736137256626 ) * Region_West + 469.5990299010082

# %%
# function to compute different metrics to check performance of a regression model
def model_performance_regression(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance

    model: regression model
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    rmse = np.sqrt(mean_squared_error(target, pred))  # to compute RMSE
    mae = mean_absolute_error(target, pred)  # to compute MAE
    mape = mean_absolute_percentage_error(target, pred)  # to compute MAPE

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "RMSE": rmse,
            "MAE": mae,
            "MAPE": mape,
        },
        index=[0],
    )

    return df_perf

# %%
# checking the performance of the model on the training set
lin_reg1_train_perf = model_performance_regression(lin_reg1, X_train[ind_vars1], y_train)
lin_reg1_train_perf
# Out:
#           RMSE          MAE      MAPE
# 0  2753.419094  2207.551603  0.096473

# %%
# checking the performance of the model on the test set
lin_reg1_test_perf = model_performance_regression(lin_reg1, X_test[ind_vars1], y_test)
lin_reg1_test_perf
# Out:
#           RMSE          MAE      MAPE
# 0  2857.307226  2226.476254  0.099616

# %%
# checking the performance of the model on the training set
lin_reg2_train_perf = model_performance_regression(lin_reg2, X_train[ind_vars2], y_train)
lin_reg2_train_perf
# Out:
#           RMSE          MAE      MAPE
# 0  2170.436447  1757.487072  0.076416

# %%
# checking the performance of the model on the test set
lin_reg2_test_perf = model_performance_regression(lin_reg2, X_test[ind_vars2], y_test)
lin_reg2_test_perf
# Out:
#           RMSE          MAE      MAPE
# 0  2179.437285  1740.589014  0.076573

# %%
# checking the performance of the model on the training set
lin_reg3_train_perf = model_performance_regression(lin_reg3, X_train, y_train)
lin_reg3_train_perf
# Out:
#           RMSE          MAE      MAPE
# 0  1940.930335  1564.829605  0.067851

# %%
# checking the performance of the model on the test set
lin_reg3_test_perf = model_performance_regression(lin_reg3, X_test, y_test)
lin_reg3_test_perf
# Out:
#           RMSE          MAE     MAPE
# 0  1907.839718  1558.392467  0.06763

# %%
# training performance comparison

# concatenating all the training performance dataframes
models_train_comp_df = pd.concat(
    [
        lin_reg1_train_perf.T,
        lin_reg2_train_perf.T,
        lin_reg3_train_perf.T,
    ],
    axis=1,
)

# defining the list of models built
models_train_comp_df.columns = [
    "Simple Linear Regression - Sales vs Advertising Expenditure",
    "Multiple Linear Regression - Sales vs Advertising Expenditure, Discount Percentage, Product Price",
    "Multiple Linear Regression - Sales vs All independent variables",
]

print("Training performance comparison:")
models_train_comp_df.T
# Out:
# Training performance comparison:
#                                                            RMSE          MAE  \
# Simple Linear Regression - Sales vs Advertising...  2753.419094  2207.551603
# Multiple Linear Regression - Sales vs Advertisi...  2170.436447  1757.487072
# Multiple Linear Regression - Sales vs All indep...  1940.930335  1564.829605
#
#                                                         MAPE
# Simple Linear Regression - Sales vs Advertising...  0.096473
# Multiple Linear Regression - Sales vs Advertisi...  0.076416
# Multiple Linear Regression - Sales vs All indep...  0.067851

# %%
# test performance comparison

# concatenating all the test performance dataframes
models_test_comp_df = pd.concat(
    [
        lin_reg1_test_perf.T,
        lin_reg2_test_perf.T,
        lin_reg3_test_perf.T,
    ],
    axis=1,
)

# defining the list of models built
models_test_comp_df.columns = [
    "Simple Linear Regression - Sales vs Advertising Expenditure",
    "Multiple Linear Regression - Sales vs Advertising Expenditure, Discount Percentage, Product Price",
    "Multiple Linear Regression - Sales vs All independent variables",
]

print("Test performance comparison:")
models_test_comp_df.T
# Out:
# Test performance comparison:
#                                                            RMSE          MAE  \
# Simple Linear Regression - Sales vs Advertising...  2857.307226  2226.476254
# Multiple Linear Regression - Sales vs Advertisi...  2179.437285  1740.589014
# Multiple Linear Regression - Sales vs All indep...  1907.839718  1558.392467
#
#                                                         MAPE
# Simple Linear Regression - Sales vs Advertising...  0.099616
# Multiple Linear Regression - Sales vs Advertisi...  0.076573
# Multiple Linear Regression - Sales vs All indep...  0.067630
