# %% [markdown]
# # Linear Regression with MSE Calculation**Objective:** Build complete linear regression models and calculate MSE metrics from scratch for deep understanding.**Approach Overview:**1. From Scratch Implementation â€” Code linear regression and MSE manually2. Validation Methods â€” Compare manual calculations with library implementations3. Error Analysis â€” Understand the relationship between residuals and MSE4. Performance Tracking â€” Monitor MSE across training and testing phases5. Optimization Insights â€” Use MSE gradients to understand model optimization

# %% [markdown]
# # Executive Summary## Linear Regression with Manual MSE CalculationThis hands-on guide builds linear regression from the ground up:- **Deep Understanding:** Implement regression and error metrics without high-level libraries- **Algorithmic Insights:** Grasp the underlying mathematics of regression optimization- **Validation Confidence:** Verify library implementations against manual calculations- **Educational Foundation:** Build strong fundamentals before advanced techniques**Implementation Topics:**- Matrix operations for linear regression- Least squares estimation from scratch- MSE calculation without sklearn- Gradient-based optimization concepts- Comparison with scikit-learn implementations**Learning Benefits:**- Deep comprehension of how regression algorithms work- Ability to debug and troubleshoot model issues- Foundation for implementing custom regression variants- Stronger intuition for advanced machine learning---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step1: import libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import sys

# Set data path based on environment
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/'
else:
    data_path = '../../data/'

#Step 2: Read the dataset
df = pd.read_csv(data_path + 'Sales.csv')

#Step 3: Prepare features and target
x = df[['Advertising Expenditure']]
y = df['Sales']

#Step 4: linear regression
model = LinearRegression()
lr = model.fit(x,y)

#Step 5: Predictions
y_pred = lr.predict(x)
