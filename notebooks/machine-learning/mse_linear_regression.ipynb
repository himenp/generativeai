# %% [markdown]
# # Mean Squared Error (MSE) in Linear Regression**Objective:** Understand and apply Mean Squared Error as a key performance metric for evaluating linear regression models.**Approach Overview:**1. Metric Definition â€” Learn MSE calculation and interpretation2. Computational Methods â€” Calculate MSE from scratch and using libraries3. Error Visualization â€” Plot prediction errors and residuals4. Comparison Analysis â€” Compare models using MSE scores5. Threshold Setting â€” Determine acceptable MSE values for applications

# %% [markdown]
# # Executive Summary## Mean Squared Error (MSE): Regression Error MeasurementThis practical guide covers MSE, a fundamental regression evaluation metric:- **Error Quantification:** Measure average squared prediction error- **Model Comparison:** Compare regression models using consistent error metrics- **Sensitivity to Outliers:** Understand how MSE responds to prediction extremes- **Performance Benchmarking:** Establish baselines for acceptable model performance**Technical Details:**- MSE formula and mathematical foundations- Relationship to residuals and prediction errors- Manual calculation and scikit-learn implementation- Squared error emphasis on large deviations- Connection to Root Mean Squared Error (RMSE)**Real-World Application:**- Evaluating regression model accuracy- Choosing between competing models- Setting performance standards- Monitoring model degradation over time---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step 1: import libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import sys

# Set data path based on environment
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/'
else:
    data_path = '../../data/'

#Step 2: read the data
df = pd.read_csv(data_path + 'Sales.csv')

#Step 3: prepare the features
X = df[['Advertising Expenditure']]
y = df['Sales']

#Step 4: model
model = LinearRegression()
model.fit(X,y)

#Step 5: Predictions
predictions = model.predict(X)

#Step 6: Calculate MSE
mse = mean_squared_error(y, predictions)
