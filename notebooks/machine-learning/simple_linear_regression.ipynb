# %% [markdown]
# # Simple Linear Regression**Objective:** Understand and implement the foundational linear regression algorithm with a single predictor variable.**Approach Overview:**1. Concept Overview â€” Learn the mathematical foundations of linear regression2. Data Preparation â€” Load and explore sample dataset3. Model Implementation â€” Implement linear regression from scratch4. Visualization â€” Plot regression line and data relationships5. Interpretation â€” Understand model coefficients and predictions

# %% [markdown]
# # Executive Summary## Simple Linear Regression FundamentalsThis tutorial covers the essentials of linear regression, the cornerstone of machine learning:- **Foundation Learning:** Understand how linear regression models relationships between variables- **Mathematical Intuition:** Grasp the concepts of fitting lines to minimize prediction error- **Hands-On Coding:** Implement regression algorithms in Python- **Real-World Application:** Apply linear regression to predict continuous values**Key Concepts:**- Linear relationship modeling between predictor (X) and target (y)- Loss functions and optimization (Ordinary Least Squares)- Model parameters: slope and intercept- Prediction and model interpretation**Learning Outcomes:**- Ability to implement linear regression from scratch- Understanding of regression metrics and model evaluation- Confidence to apply linear regression to real problems- Foundation for advanced regression techniques---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step 1: import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import sys

# Set data path based on environment
if 'google.colab' in sys.modules:
    # Mount Google Drive in Colab
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/'
else:
    data_path = '../../data/'

#Step 2: Read the dataset
df = pd.read_csv(data_path + 'Sales.csv')

#Step 3: Prepare features and target
X = df[['Advertising Expenditure']]
y = df['Sales']

#Step 4: splitting the data in 80:20 ratio for train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X,    # specifying the independent variables
    y,    # specifying the dependent variable
    test_size=0.20,    # specifying the size of the test set as a fraction of the whole data
    random_state=42    # specifying a seed value to enable reproducible results
)

#Step 5: linear regression
model = LinearRegression()
model.fit(X_train, y_train)

#Step 6: Predictions
y_pred = model.predict(X_test)

#Step 6: Evaluating the model
r_squared = r2_score(y_test, y_pred)

# %%
# Display the results
print(f"R² Score: {r_squared:.4f}")
print(f"\nModel Coefficient: {model.coef_[0]:.4f}")
print(f"Model Intercept: {model.intercept_:.4f}")
# Out:
# R² Score: 0.3855
#
# Model Coefficient: 28.6675
# Model Intercept: 6435.8913
