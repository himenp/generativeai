# %% [markdown]
# # Linear Regression: Price vs Sales**Objective:** Analyze the relationship between product pricing and sales volume using linear regression modeling.**Approach Overview:**1. Data Exploration â€” Visualize price and sales data distributions2. Correlation Analysis â€” Examine relationships between variables3. Model Development â€” Build regression model for price-sales prediction4. Elasticity Calculation â€” Quantify pricing sensitivity of demand5. Business Insights â€” Extract actionable pricing recommendations

# %% [markdown]
# # Executive Summary## Price-Sales Analysis with Linear RegressionThis case study applies linear regression to pricing strategy optimization:- **Demand Analysis:** Understand how pricing affects sales volume- **Elasticity Metrics:** Calculate price sensitivity of customer demand- **Revenue Optimization:** Find optimal price points for maximum revenue- **Competitive Positioning:** Benchmark pricing against market dynamics**Analysis Components:**- Historical price and sales data exploration- Linear regression modeling of price-volume relationships- Elasticity coefficient interpretation- Scenario analysis under different pricing strategies**Business Applications:**- Dynamic pricing strategy development- Inventory planning based on price sensitivity- Profit maximization recommendations- Market positioning decisions---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step 1: importing libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
import sys

# Set data path based on environment
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/'
else:
    data_path = '../../data/'

#Step 2: Reading the data
df = pd.read_csv(data_path + 'Sales.csv')

#Step 3: Preparing the data
x = df[['Advertising Expenditure']]
y = df['Sales']

#Step 4: Model
model = LinearRegression()
lr = model.fit(x,y)
