# %% [markdown]
# # Label Encoding for Linear Regression**Objective:** Master label encoding technique for converting categorical variables into numeric form for regression models.**Approach Overview:**1. Label Encoding Basics â€” Understand the label encoding technique2. Implementation Methods â€” Learn to apply label encoding in Python3. Appropriate Usage â€” Know when label encoding is suitable vs. alternatives4. Model Integration â€” Incorporate label-encoded variables into regression5. Interpretation Challenges â€” Address coefficient interpretation with label encoding

# %% [markdown]
# # Executive Summary## Label Encoding for Categorical VariablesThis guide covers label encoding, a simple dimensional approach to categorical variables:- **Simplicity:** Use single-column encoding instead of expanding dummy variables- **Ordinal Data:** Perfect for naturally ordered categorical variables- **Implementation:** Quickly convert categorical values to integers- **Efficiency:** Reduce feature space compared to one-hot encoding**Technical Details:**- Label encoding concept and implementation- Mapping categorical values to integers- Ordinal vs. nominal variable considerations- Scikit-learn LabelEncoder usage- Handling unknown categories**When to Use:**- Ordinal categorical variables with natural ordering- Tree-based models that handle label encoding well- Feature space optimization needs- Contrast with one-hot encoding approaches---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step 1: import libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
import sys
import os

#Step 2: set data path for local/Colab
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/data.csv'
else:
    data_path = os.path.abspath(os.path.join('..','..','data','data.csv'))

#Step 3: read data
df = pd.read_csv(data_path)

#Step 4: apply label encoding
label_encoder = LabelEncoder()
encoded_job = label_encoder.fit_transform(df['Job'])

#Step 5: Prepare the target
X = encoded_job.reshape(-1, 1)
y = df['Age']

#Step 6: Create a model
model = LinearRegression()
model.fit(X, y)
