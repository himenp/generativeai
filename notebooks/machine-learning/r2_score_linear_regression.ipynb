# %% [markdown]
# # RÂ² Score Fundamentals**Objective:** Master the RÂ² score metric and its proper interpretation for assessing linear regression model performance.**Approach Overview:**1. Foundational Concepts â€” Understand RÂ² meaning and range2. Calculation Details â€” Learn RÂ² computation from mathematical foundations3. Interpretation Guidance â€” Know what different RÂ² values indicate4. Common Pitfalls â€” Avoid misinterpreting RÂ² scores5. Practical Application â€” Use RÂ² effectively in model evaluation workflows

# %% [markdown]
# # Executive Summary## RÂ² Score: Foundation for Regression EvaluationThis comprehensive guide covers RÂ² score fundamentals:- **Variance Explanation:** Understand RÂ² as the proportion of variance explained by the model- **Scale Interpretation:** Learn the 0-1 scale and what values mean for different domains- **Comparison Tool:** Use RÂ² to compare models and track improvement- **Communication Value:** Present model quality to stakeholders clearly**Core Concepts:**- RÂ² definition and mathematical formula- Relationship to Sum of Squared Residuals- Range of 0 to 1 interpretation- Negative RÂ² for poor models- Factors affecting RÂ² scores**Practical Guidance:**- Evaluating whether model performance is acceptable- Comparing multiple regression models objectively- Understanding limitations of RÂ² as sole metric- Combining RÂ² with other metrics for robust evaluation---

# %%
# === BOOTSTRAP: Find project root & setup sys.path ===
import sys
from pathlib import Path

print("=" * 60)
print("BOOTSTRAP")
print("=" * 60)

def find_project_root(markers=("requirements.txt", "config.yaml", ".git")):
    cwd = Path.cwd().resolve()
    for path in [cwd] + list(cwd.parents):
        if any((path / marker).exists() for marker in markers):
            return path
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    print(f"✓ Added to sys.path")

print("=" * 60)

# %%
# === LOAD CONFIGURATION ===
import yaml

print("=" * 60)
print("LOAD CONFIG")
print("=" * 60)

config_path = PROJECT_ROOT / "config" / "config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config not found at {config_path}")

with open(config_path, "r", encoding="utf-8") as f:
    config = yaml.safe_load(f) or {}

project_name = config.get('project_name', 'GenerativeAI')
print(f"Project name: {project_name}")
print("✓ Config loaded")
print("=" * 60)

# %%
# === IMPORTS & SETUP ===
import sys

print("=" * 60)
print("IMPORTS & SETUP")
print("=" * 60)

# Clear any cached utils modules to fix circular import
for module in list(sys.modules.keys()):
    if module.startswith('utils'):
        del sys.modules[module]

# Ensure sys.path includes PROJECT_ROOT
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Import utilities
from utils.helpers import load_csv, set_seed
from utils.config import load_config
print("✓ Utils imported")

# Standard data science imports
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
print("✓ Libraries imported")

# Load config and set random seed
cfg = load_config()
set_seed(cfg['model']['random_state'])
print(f"✓ Seed set to {cfg['model']['random_state']}")

print("=" * 60)

# %%
#Step 1: import libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import sys

# Set data path based on environment
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/My Drive/Projects/GenerativeAI/data/'
else:
    data_path = '../../data/'

#Step 2: read the data
df = pd.read_csv(data_path + 'Sales.csv')

#Step 3: prepare the features
X = df[['Advertising Expenditure']]
y = df['Sales']

#Step 4: model
model = LinearRegression()
model.fit(X,y)

#Step 5: Compute R2
r2 = r2_score(y, model.predict(X))
